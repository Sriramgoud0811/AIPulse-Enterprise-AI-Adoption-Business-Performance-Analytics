# %%
import pandas as pd
import numpy as np

# Load raw datasets
company = pd.read_csv("../data/raw/ai_company_adoption.csv")
industry = pd.read_csv("../data/raw/ai_industry_summary.csv")
country = pd.read_csv("../data/raw/country_ai_index.csv")

# Create copies (work on these only)
company_copy = company.copy()
industry_copy = industry.copy()
country_copy = country.copy()

# %%
# Profile dataset
company_copy.shape
company_copy.info()
company_copy.dtypes
company_copy.describe()

# Missing values
company_copy.isnull().sum()

# Duplicate check
company_copy["response_id"].duplicated().sum()
company_copy["company_id"].duplicated().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150000 entries, 0 to 149999
# Data columns (total 43 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   response_id                  150000 non-null  int64
#  1   company_id                   150000 non-null  object
#  2   survey_year                  150000 non-null  int64
#  3   quarter                      150000 non-null  object
#  4   country                      150000 non-null  object
#  5   region                       150000 non-null  object
#  6   industry                     150000 non-null  object
#  7   company_size                 150000 non-null  object
#  8   num_employees                150000 non-null  int64
#  9   annual_revenue_usd_millions  150000 non-null  float64
#  10  company_founding_year        150000 non-null  int64
#  11  company_age                  150000 non-null  int64
# ...

# %%
# Profile dataset
company_copy.shape
company_copy.info()
company_copy.dtypes
company_copy.describe()

# Missing values
company_copy.isnull().sum()

# Duplicate check
company_copy["response_id"].duplicated().sum()
company_copy["company_id"].duplicated().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150000 entries, 0 to 149999
# Data columns (total 43 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   response_id                  150000 non-null  int64
#  1   company_id                   150000 non-null  object
#  2   survey_year                  150000 non-null  int64
#  3   quarter                      150000 non-null  object
#  4   country                      150000 non-null  object
#  5   region                       150000 non-null  object
#  6   industry                     150000 non-null  object
#  7   company_size                 150000 non-null  object
#  8   num_employees                150000 non-null  int64
#  9   annual_revenue_usd_millions  150000 non-null  float64
#  10  company_founding_year        150000 non-null  int64
#  11  company_age                  150000 non-null  int64
# ...

# %%
company_copy.dtypes
industry_copy.dtypes
country_copy.dtypes
# Out:
# country                        object
# region                         object
# gdp_per_capita                float64
# internet_penetration          float64
# digital_maturity_index        float64
# country_ai_policy              object
# ai_patent_filings_2024          int64
# ai_researchers_per_million    float64
# dtype: object

# %%
company_copy.isnull().sum()

industry_copy.isnull().sum()

country_copy.isnull().sum()
# Out:
# country                       0
# region                        0
# gdp_per_capita                0
# internet_penetration          0
# digital_maturity_index        0
# country_ai_policy             0
# ai_patent_filings_2024        0
# ai_researchers_per_million    0
# dtype: int64

# %%
company_copy.isnull().sum().sum()

industry_copy.isnull().sum().sum()

country_copy.isnull().sum().sum()
# Out:
# np.int64(0)
