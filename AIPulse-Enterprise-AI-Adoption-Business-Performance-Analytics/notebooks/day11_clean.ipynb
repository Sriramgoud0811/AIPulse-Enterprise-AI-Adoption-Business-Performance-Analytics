# %% [markdown]
# #### Task 1 Reproduce cleaning in pandas notebook

# %% [markdown]
# import pandas as pd
#
# df_company = pd.read_csv("../data/raw/ai_company_adoption.csv")

# %%
# Check data
df_company.head()
# Out:
#    response_id  company_id  survey_year quarter country  region   industry  \
# 0            1  COMP-00001         2023      Q1   Italy  Europe  Education
# 1            2  COMP-00001         2023      Q2   Italy  Europe  Education
# 2            3  COMP-00001         2023      Q3   Italy  Europe  Education
# 3            4  COMP-00001         2023      Q4   Italy  Europe  Education
# 4            5  COMP-00001         2024      Q1   Italy  Europe  Education
#
#   company_size  num_employees  annual_revenue_usd_millions  ...  \
# 0      Startup             57                        48.31  ...
# 1      Startup             57                        48.31  ...
# 2      Startup             57                        48.31  ...
# 3      Startup             57                        48.31  ...
# 4      Startup             57                        48.31  ...
#
#    productivity_change_percent  jobs_displaced jobs_created  \
# 0                         2.65               1            1
# ...

# %%
df_company.info()
df_company.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150000 entries, 0 to 149999
# Data columns (total 43 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   response_id                  150000 non-null  int64
#  1   company_id                   150000 non-null  object
#  2   survey_year                  150000 non-null  int64
#  3   quarter                      150000 non-null  object
#  4   country                      150000 non-null  object
#  5   region                       150000 non-null  object
#  6   industry                     150000 non-null  object
#  7   company_size                 150000 non-null  object
#  8   num_employees                150000 non-null  int64
#  9   annual_revenue_usd_millions  150000 non-null  float64
#  10  company_founding_year        150000 non-null  int64
#  11  company_age                  150000 non-null  int64
# ...

# %%
print("Missing values before cleaning:")
print(df_company.isnull().sum())

# Cleaning steps...
print("------------------------------------------------------")
print("Missing values after cleaning:")
print(df_company.isnull().sum())
# Out:
# Missing values before cleaning:
# response_id                    0
# company_id                     0
# survey_year                    0
# quarter                        0
# country                        0
# region                         0
# industry                       0
# company_size                   0
# num_employees                  0
# annual_revenue_usd_millions    0
# company_founding_year          0
# company_age                    0
# company_age_group              0
# ai_adoption_rate               0
# ai_adoption_stage              0
# years_using_ai                 0
# ai_primary_tool                0
# num_ai_tools_used              0
# ai_use_case                    0
# ai_projects_active             0
# ai_training_hours              0
# ai_budget_percentage           0
# ai_maturity_score              0
# ai_failure_rate                0
# ai_investment_per_employee     0
# regulatory_compliance_score    0
# data_privacy_level             0
# ...

# %%
# Check duplicates
df_company.duplicated().sum()
# Out:
# np.int64(0)

# %%
print("Duplicate rows before:", df_company.duplicated().sum())

df_company = df_company.drop_duplicates()

print("Duplicate rows after:", df_company.duplicated().sum())
# Out:
# Duplicate rows before: 0
# Duplicate rows after: 0

# %%
# Check data types
df_company.dtypes
# Out:
# response_id                      int64
# company_id                      object
# survey_year                      int64
# quarter                         object
# country                         object
# region                          object
# industry                        object
# company_size                    object
# num_employees                    int64
# annual_revenue_usd_millions    float64
# company_founding_year            int64
# company_age                      int64
# company_age_group               object
# ai_adoption_rate               float64
# ai_adoption_stage               object
# years_using_ai                   int64
# ai_primary_tool                 object
# num_ai_tools_used                int64
# ai_use_case                     object
# ai_projects_active               int64
# ai_training_hours              float64
# ai_budget_percentage           float64
# ai_maturity_score              float64
# ai_failure_rate                float64
# ...

# %% [markdown]
# #### dataset 2 ai_industry_summary.csv

# %%
df_industry = pd.read_csv("../data/raw/ai_industry_summary.csv")

# Check data
df_industry.head()
df_industry.info()
df_industry.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 8 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   industry                         9 non-null      object
#  1   avg_ai_adoption_rate             9 non-null      float64
#  2   avg_productivity_change_percent  9 non-null      float64
#  3   avg_ai_maturity_score            9 non-null      float64
#  4   avg_ai_failure_rate              9 non-null      float64
#  5   avg_jobs_displaced               9 non-null      float64
#  6   avg_jobs_created                 9 non-null      float64
#  7   avg_customer_satisfaction        9 non-null      float64
# dtypes: float64(7), object(1)
# memory usage: 708.0+ bytes
# (9, 8)

# %%
# Check missing values
df_industry.isnull().sum()
# Out:
# industry                           0
# avg_ai_adoption_rate               0
# avg_productivity_change_percent    0
# avg_ai_maturity_score              0
# avg_ai_failure_rate                0
# avg_jobs_displaced                 0
# avg_jobs_created                   0
# avg_customer_satisfaction          0
# dtype: int64

# %%
# Check duplicates
df_industry.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Remove duplicates

print("Duplicates after removal:", df_company.duplicated().sum())
# Out:
# Duplicates after removal: 0

# %%
# Check data types
df_industry.dtypes
# Out:
# industry                            object
# avg_ai_adoption_rate               float64
# avg_productivity_change_percent    float64
# avg_ai_maturity_score              float64
# avg_ai_failure_rate                float64
# avg_jobs_displaced                 float64
# avg_jobs_created                   float64
# avg_customer_satisfaction          float64
# dtype: object

# %% [markdown]
# #### Dataset 3: country_ai_index.csv

# %%
df_country = pd.read_csv("../data/raw/country_ai_index.csv")

# Check data
df_country.head()
df_country.info()
df_country.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 8 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   country                     30 non-null     object
#  1   region                      30 non-null     object
#  2   gdp_per_capita              30 non-null     float64
#  3   internet_penetration        30 non-null     float64
#  4   digital_maturity_index      30 non-null     float64
#  5   country_ai_policy           30 non-null     object
#  6   ai_patent_filings_2024      30 non-null     int64
#  7   ai_researchers_per_million  30 non-null     float64
# dtypes: float64(4), int64(1), object(3)
# memory usage: 2.0+ KB
# (30, 8)

# %%
# Check missing values
df_country.isnull().sum()
# Out:
# country                       0
# region                        0
# gdp_per_capita                0
# internet_penetration          0
# digital_maturity_index        0
# country_ai_policy             0
# ai_patent_filings_2024        0
# ai_researchers_per_million    0
# dtype: int64

# %%
# Check duplicates
df_country.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Remove duplicates
print("duplicate remove: ", df_country.drop_duplicates())
# Out:
# duplicate remove:           country         region  gdp_per_capita  internet_penetration  \
# 0            USA  North America        72596.06                 92.10
# 1         Canada  North America        55834.08                 96.78
# 2        Germany         Europe        54777.23                 91.98
# 3             UK         Europe        52827.64                 91.41
# 4         France         Europe        47719.02                 92.23
# 5    Netherlands         Europe        57719.04                 93.17
# 6         Sweden         Europe        62895.06                 96.31
# 7          Spain         Europe        42920.92                 87.06
# 8          Italy         Europe        39436.63                 86.01
# 9         Poland         Europe        26651.07                 88.30
# 10         India           Asia         7443.90                 61.11
# 11         China           Asia        12441.12                 75.26
# ...

# %%
print("Industries:", df_company["industry"].nunique())
print("Countries:", df_company["country"].nunique())
print("AI Stages:", df_company["ai_adoption_stage"].nunique())
# Out:
# Industries: 9
# Countries: 30
# AI Stages: 4

# %% [markdown]
# #### task 2 Assert row counts and null counts match the cleaning plan

# %%
# Row count
print("Total Rows:", len(df_company))

# Null count
print("\nNull Counts:")
print(df_company.isnull().sum())
# Out:
# Total Rows: 150000
#
# Null Counts:
# response_id                    0
# company_id                     0
# survey_year                    0
# quarter                        0
# country                        0
# region                         0
# industry                       0
# company_size                   0
# num_employees                  0
# annual_revenue_usd_millions    0
# company_founding_year          0
# company_age                    0
# company_age_group              0
# ai_adoption_rate               0
# ai_adoption_stage              0
# years_using_ai                 0
# ai_primary_tool                0
# num_ai_tools_used              0
# ai_use_case                    0
# ai_projects_active             0
# ai_training_hours              0
# ai_budget_percentage           0
# ai_maturity_score              0
# ai_failure_rate                0
# ai_investment_per_employee     0
# regulatory_compliance_score    0
# data_privacy_level             0
# ...

# %%
# Row count
print("Total Rows:", len(df_industry))

# Null count
print("\nNull Counts:")
print(df_industry.isnull().sum())
# Out:
# Total Rows: 9
#
# Null Counts:
# industry                           0
# avg_ai_adoption_rate               0
# avg_productivity_change_percent    0
# avg_ai_maturity_score              0
# avg_ai_failure_rate                0
# avg_jobs_displaced                 0
# avg_jobs_created                   0
# avg_customer_satisfaction          0
# dtype: int64

# %%
# Row count
print("Total Rows:", len(df_country))

# Null count
print("\nNull Counts:")
print(df_country.isnull().sum())
# Out:
# Total Rows: 30
#
# Null Counts:
# country                       0
# region                        0
# gdp_per_capita                0
# internet_penetration          0
# digital_maturity_index        0
# country_ai_policy             0
# ai_patent_filings_2024        0
# ai_researchers_per_million    0
# dtype: int64
